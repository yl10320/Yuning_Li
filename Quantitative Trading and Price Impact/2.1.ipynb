# %%
import pandas as pd
import numpy as np
import statsmodels.api as sm
import os
import matplotlib.pyplot as plt
import matplotlib.dates as mdates
import matplotlib.ticker as mtick
from tqdm import tqdm
import psutil
import zipfile 
import shutil

# %%
current_dir = os.getcwd()
print(current_dir)
# Out:
# C:\Users\zkr_l\Desktop\Trading\CW

# %% [markdown]
# Unzip data and define paths to data:

# %%
path_to_zip_file = f"{current_dir}/data/binSamples.zip"
with zipfile.ZipFile(path_to_zip_file, 'r') as zip_ref:
    zip_ref.extractall(current_dir)

path_to_zip_file = f"{current_dir}/data/fillSamples.zip"
with zipfile.ZipFile(path_to_zip_file, 'r') as zip_ref:
    zip_ref.extractall(current_dir)

# %%
year = "2019"
bin_sample_path = f"{current_dir}/data/binSamples/"
fill_sample_path = f"{current_dir}/data/fillSamples/"
result_path = f"{current_dir}/data/Results/"

# %% [markdown]
# Prepare dataframes:

# %%
stock_info_dfs = []

for month_int in tqdm(range(1, 13)):
    # read data by months
    month = "%02d" % month_int
    filename = f"bin{year}{month}.csv"
    bin_sample_df = pd.read_csv(bin_sample_path + filename)
    
    # generate traded volume dataframe indexed by stock and date
    traded_volume_df = bin_sample_df[["stock", "date", "trade", "time"]].pivot(index=["stock", "date"], columns="time", values="trade").fillna(0).astype(int)
    filename = f"inter_results_trade_volume_df_{year}{month}.csv"
    traded_volume_df.to_csv(result_path + filename)

    # generate mid price dataframe (at the end of the bin window) indexed by stock and date
    px_df = bin_sample_df[["stock", "date", "midEnd", "time"]].pivot(index=["stock", "date"], columns="time", values="midEnd").fillna(method="ffill", axis="columns").fillna(method="bfill", axis="columns")
    filename = f"inter_results_px_df_{year}{month}.csv"
    px_df.to_csv(result_path + filename)

    # generate spread dataframe (at start of bin window) indexed by stock and date
    spread_df = bin_sample_df[["stock", "date", "spread", "time"]].pivot(index=["stock", "date"], columns="time", values="spread").fillna(method="ffill", axis="columns").fillna(method="bfill", axis="columns")
    filename = f"inter_results_spread_df_{year}{month}.csv"
    spread_df.to_csv(result_path + filename)

    # generate daily price return volatility std and traded volume dataframe
    monthly_stock_info_df = pd.DataFrame({
        # Compute the price return volatility as a standard deviation row-wise
        "px_vol": px_df.pct_change(1, axis="columns").std(axis="columns"),
        # Compute the total daily traded volume as the sum of all volumes in either direction using abp().sum over rows (axis columns)
        "volume": traded_volume_df.abs().sum(axis="columns"),
    }).reset_index()
    stock_info_dfs.append(monthly_stock_info_df.copy())

stock_info_df = pd.concat(stock_info_dfs).reset_index()
filename = f"inter_results_stock_info_df_{year}all.csv"
stock_info_df.to_csv(result_path + filename)
# Out:
#   0%|          | 0/12 [00:00<?, ?it/s]C:\Users\zkr_l\AppData\Local\Temp\ipykernel_21276\1933955430.py:15: FutureWarning: DataFrame.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   px_df = bin_sample_df[["stock", "date", "midEnd", "time"]].pivot(index=["stock", "date"], columns="time", values="midEnd").fillna(method="ffill", axis="columns").fillna(method="bfill", axis="columns")
# C:\Users\zkr_l\AppData\Local\Temp\ipykernel_21276\1933955430.py:20: FutureWarning: DataFrame.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   spread_df = bin_sample_df[["stock", "date", "spread", "time"]].pivot(index=["stock", "date"], columns="time", values="spread").fillna(method="ffill", axis="columns").fillna(method="bfill", axis="columns")
#   8%|▊         | 1/12 [00:17<03:17, 17.99s/it]C:\Users\zkr_l\AppData\Local\Temp\ipykernel_21276\1933955430.py:15: FutureWarning: DataFrame.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   px_df = bin_sample_df[["stock", "date", "midEnd", "time"]].pivot(index=["stock", "date"], columns="time", values="midEnd").fillna(method="ffill", axis="columns").fillna(method="bfill", axis="columns")
# C:\Users\zkr_l\AppData\Local\Temp\ipykernel_21276\1933955430.py:20: FutureWarning: DataFrame.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   spread_df = bin_sample_df[["stock", "date", "spread", "time"]].pivot(index=["stock", "date"], columns="time", values="spread").fillna(method="ffill", axis="columns").fillna(method="bfill", axis="columns")
#  17%|█▋        | 2/12 [00:34<02:51, 17.17s/it]C:\Users\zkr_l\AppData\Local\Temp\ipykernel_21276\1933955430.py:15: FutureWarning: DataFrame.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   px_df = bin_sample_df[["stock", "date", "midEnd", "time"]].pivot(index=["stock", "date"], columns="time", values="midEnd").fillna(method="ffill", axis="columns").fillna(method="bfill", axis="columns")
# C:\Users\zkr_l\AppData\Local\Temp\ipykernel_21276\1933955430.py:20: FutureWarning: DataFrame.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   spread_df = bin_sample_df[["stock", "date", "spread", "time"]].pivot(index=["stock", "date"], columns="time", values="spread").fillna(method="ffill", axis="columns").fillna(method="bfill", axis="columns")
#  25%|██▌       | 3/12 [00:52<02:39, 17.67s/it]C:\Users\zkr_l\AppData\Local\Temp\ipykernel_21276\1933955430.py:15: FutureWarning: DataFrame.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   px_df = bin_sample_df[["stock", "date", "midEnd", "time"]].pivot(index=["stock", "date"], columns="time", values="midEnd").fillna(method="ffill", axis="columns").fillna(method="bfill", axis="columns")
# C:\Users\zkr_l\AppData\Local\Temp\ipykernel_21276\1933955430.py:20: FutureWarning: DataFrame.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   spread_df = bin_sample_df[["stock", "date", "spread", "time"]].pivot(index=["stock", "date"], columns="time", values="spread").fillna(method="ffill", axis="columns").fillna(method="bfill", axis="columns")
#  33%|███▎      | 4/12 [01:10<02:22, 17.86s/it]C:\Users\zkr_l\AppData\Local\Temp\ipykernel_21276\1933955430.py:15: FutureWarning: DataFrame.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   px_df = bin_sample_df[["stock", "date", "midEnd", "time"]].pivot(index=["stock", "date"], columns="time", values="midEnd").fillna(method="ffill", axis="columns").fillna(method="bfill", axis="columns")
# C:\Users\zkr_l\AppData\Local\Temp\ipykernel_21276\1933955430.py:20: FutureWarning: DataFrame.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   spread_df = bin_sample_df[["stock", "date", "spread", "time"]].pivot(index=["stock", "date"], columns="time", values="spread").fillna(method="ffill", axis="columns").fillna(method="bfill", axis="columns")
#  42%|████▏     | 5/12 [01:30<02:09, 18.54s/it]C:\Users\zkr_l\AppData\Local\Temp\ipykernel_21276\1933955430.py:15: FutureWarning: DataFrame.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   px_df = bin_sample_df[["stock", "date", "midEnd", "time"]].pivot(index=["stock", "date"], columns="time", values="midEnd").fillna(method="ffill", axis="columns").fillna(method="bfill", axis="columns")
# C:\Users\zkr_l\AppData\Local\Temp\ipykernel_21276\1933955430.py:20: FutureWarning: DataFrame.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   spread_df = bin_sample_df[["stock", "date", "spread", "time"]].pivot(index=["stock", "date"], columns="time", values="spread").fillna(method="ffill", axis="columns").fillna(method="bfill", axis="columns")
#  50%|█████     | 6/12 [01:48<01:50, 18.38s/it]C:\Users\zkr_l\AppData\Local\Temp\ipykernel_21276\1933955430.py:15: FutureWarning: DataFrame.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   px_df = bin_sample_df[["stock", "date", "midEnd", "time"]].pivot(index=["stock", "date"], columns="time", values="midEnd").fillna(method="ffill", axis="columns").fillna(method="bfill", axis="columns")
# C:\Users\zkr_l\AppData\Local\Temp\ipykernel_21276\1933955430.py:20: FutureWarning: DataFrame.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   spread_df = bin_sample_df[["stock", "date", "spread", "time"]].pivot(index=["stock", "date"], columns="time", values="spread").fillna(method="ffill", axis="columns").fillna(method="bfill", axis="columns")
#  58%|█████▊    | 7/12 [02:07<01:32, 18.49s/it]C:\Users\zkr_l\AppData\Local\Temp\ipykernel_21276\1933955430.py:15: FutureWarning: DataFrame.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   px_df = bin_sample_df[["stock", "date", "midEnd", "time"]].pivot(index=["stock", "date"], columns="time", values="midEnd").fillna(method="ffill", axis="columns").fillna(method="bfill", axis="columns")
# C:\Users\zkr_l\AppData\Local\Temp\ipykernel_21276\1933955430.py:20: FutureWarning: DataFrame.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   spread_df = bin_sample_df[["stock", "date", "spread", "time"]].pivot(index=["stock", "date"], columns="time", values="spread").fillna(method="ffill", axis="columns").fillna(method="bfill", axis="columns")
#  67%|██████▋   | 8/12 [02:26<01:14, 18.59s/it]C:\Users\zkr_l\AppData\Local\Temp\ipykernel_21276\1933955430.py:15: FutureWarning: DataFrame.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   px_df = bin_sample_df[["stock", "date", "midEnd", "time"]].pivot(index=["stock", "date"], columns="time", values="midEnd").fillna(method="ffill", axis="columns").fillna(method="bfill", axis="columns")
# C:\Users\zkr_l\AppData\Local\Temp\ipykernel_21276\1933955430.py:20: FutureWarning: DataFrame.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   spread_df = bin_sample_df[["stock", "date", "spread", "time"]].pivot(index=["stock", "date"], columns="time", values="spread").fillna(method="ffill", axis="columns").fillna(method="bfill", axis="columns")
#  75%|███████▌  | 9/12 [02:43<00:54, 18.05s/it]C:\Users\zkr_l\AppData\Local\Temp\ipykernel_21276\1933955430.py:15: FutureWarning: DataFrame.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   px_df = bin_sample_df[["stock", "date", "midEnd", "time"]].pivot(index=["stock", "date"], columns="time", values="midEnd").fillna(method="ffill", axis="columns").fillna(method="bfill", axis="columns")
# C:\Users\zkr_l\AppData\Local\Temp\ipykernel_21276\1933955430.py:20: FutureWarning: DataFrame.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   spread_df = bin_sample_df[["stock", "date", "spread", "time"]].pivot(index=["stock", "date"], columns="time", values="spread").fillna(method="ffill", axis="columns").fillna(method="bfill", axis="columns")
#  83%|████████▎ | 10/12 [03:04<00:38, 19.11s/it]C:\Users\zkr_l\AppData\Local\Temp\ipykernel_21276\1933955430.py:15: FutureWarning: DataFrame.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   px_df = bin_sample_df[["stock", "date", "midEnd", "time"]].pivot(index=["stock", "date"], columns="time", values="midEnd").fillna(method="ffill", axis="columns").fillna(method="bfill", axis="columns")
# C:\Users\zkr_l\AppData\Local\Temp\ipykernel_21276\1933955430.py:20: FutureWarning: DataFrame.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   spread_df = bin_sample_df[["stock", "date", "spread", "time"]].pivot(index=["stock", "date"], columns="time", values="spread").fillna(method="ffill", axis="columns").fillna(method="bfill", axis="columns")
#  92%|█████████▏| 11/12 [03:21<00:18, 18.55s/it]C:\Users\zkr_l\AppData\Local\Temp\ipykernel_21276\1933955430.py:15: FutureWarning: DataFrame.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   px_df = bin_sample_df[["stock", "date", "midEnd", "time"]].pivot(index=["stock", "date"], columns="time", values="midEnd").fillna(method="ffill", axis="columns").fillna(method="bfill", axis="columns")
# C:\Users\zkr_l\AppData\Local\Temp\ipykernel_21276\1933955430.py:20: FutureWarning: DataFrame.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   spread_df = bin_sample_df[["stock", "date", "spread", "time"]].pivot(index=["stock", "date"], columns="time", values="spread").fillna(method="ffill", axis="columns").fillna(method="bfill", axis="columns")
# 100%|██████████| 12/12 [03:38<00:00, 18.17s/it]

# %% [markdown]
# Collecting pairs of months together to take 20-day rolling average.

# %%
stock_info_dfs = []

for month_int in tqdm(range(1, 12)):
    # read data by months
    month = "%02d" % month_int
    filename = f"bin{year}{month}.csv"
    bin_sample_df = pd.read_csv(bin_sample_path + filename)
    
    month2 = "%02d" % (month_int+1)
    filename2 = f"bin{year}{month2}.csv"
    bin_sample_df2 = pd.read_csv(bin_sample_path + filename2)
    
    traded_volume_df = bin_sample_df[["stock", "date", "trade", "time"]].pivot(index=["stock", "date"], columns="time", values="trade").fillna(0).astype(int)
    traded_volume_df2 = bin_sample_df2[["stock", "date", "trade", "time"]].pivot(index=["stock", "date"], columns="time", values="trade").fillna(0).astype(int)
    
    px_df = bin_sample_df[["stock", "date", "midEnd", "time"]].pivot(index=["stock", "date"], columns="time", values="midEnd").fillna(method="ffill", axis="columns").fillna(method="bfill", axis="columns")
    px_df2 = bin_sample_df2[["stock", "date", "midEnd", "time"]].pivot(index=["stock", "date"], columns="time", values="midEnd").fillna(method="ffill", axis="columns").fillna(method="bfill", axis="columns")
    
    
    # generate daily price return volatility std and traded volume dataframe
    monthly_stock_info_df = pd.DataFrame({
        # Compute the price return volatility as a standard deviation row-wise
        "px_vol": px_df.pct_change(1, axis="columns").std(axis="columns"),
        # Compute the total daily traded volume as the sum of all volumes in either direction using abp().sum over rows (axis columns)
        "volume": traded_volume_df.abs().sum(axis="columns"),
    }).reset_index()
    monthly_stock_info_df2 = pd.DataFrame({
        # Compute the price return volatility as a standard deviation row-wise
        "px_vol": px_df2.pct_change(1, axis="columns").std(axis="columns"),
        # Compute the total daily traded volume as the sum of all volumes in either direction using abp().sum over rows (axis columns)
        "volume": traded_volume_df2.abs().sum(axis="columns"),
    }).reset_index()
    
    stock_info_dfs = [monthly_stock_info_df.copy(), monthly_stock_info_df2.copy()]
    stock_info_df = pd.concat(stock_info_dfs).reset_index()
    filename = f"stock_info_df_{year}{month}{month2}.csv"
    stock_info_df.to_csv(result_path + filename)
# Out:
#   0%|          | 0/11 [00:00<?, ?it/s]C:\Users\zkr_l\AppData\Local\Temp\ipykernel_21276\3614617416.py:16: FutureWarning: DataFrame.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   px_df = bin_sample_df[["stock", "date", "midEnd", "time"]].pivot(index=["stock", "date"], columns="time", values="midEnd").fillna(method="ffill", axis="columns").fillna(method="bfill", axis="columns")
# C:\Users\zkr_l\AppData\Local\Temp\ipykernel_21276\3614617416.py:17: FutureWarning: DataFrame.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   px_df2 = bin_sample_df2[["stock", "date", "midEnd", "time"]].pivot(index=["stock", "date"], columns="time", values="midEnd").fillna(method="ffill", axis="columns").fillna(method="bfill", axis="columns")
#   9%|▉         | 1/11 [00:17<02:59, 17.93s/it]C:\Users\zkr_l\AppData\Local\Temp\ipykernel_21276\3614617416.py:16: FutureWarning: DataFrame.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   px_df = bin_sample_df[["stock", "date", "midEnd", "time"]].pivot(index=["stock", "date"], columns="time", values="midEnd").fillna(method="ffill", axis="columns").fillna(method="bfill", axis="columns")
# C:\Users\zkr_l\AppData\Local\Temp\ipykernel_21276\3614617416.py:17: FutureWarning: DataFrame.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   px_df2 = bin_sample_df2[["stock", "date", "midEnd", "time"]].pivot(index=["stock", "date"], columns="time", values="midEnd").fillna(method="ffill", axis="columns").fillna(method="bfill", axis="columns")
#  18%|█▊        | 2/11 [00:36<02:42, 18.08s/it]C:\Users\zkr_l\AppData\Local\Temp\ipykernel_21276\3614617416.py:16: FutureWarning: DataFrame.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   px_df = bin_sample_df[["stock", "date", "midEnd", "time"]].pivot(index=["stock", "date"], columns="time", values="midEnd").fillna(method="ffill", axis="columns").fillna(method="bfill", axis="columns")
# C:\Users\zkr_l\AppData\Local\Temp\ipykernel_21276\3614617416.py:17: FutureWarning: DataFrame.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   px_df2 = bin_sample_df2[["stock", "date", "midEnd", "time"]].pivot(index=["stock", "date"], columns="time", values="midEnd").fillna(method="ffill", axis="columns").fillna(method="bfill", axis="columns")
#  27%|██▋       | 3/11 [00:54<02:26, 18.28s/it]C:\Users\zkr_l\AppData\Local\Temp\ipykernel_21276\3614617416.py:16: FutureWarning: DataFrame.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   px_df = bin_sample_df[["stock", "date", "midEnd", "time"]].pivot(index=["stock", "date"], columns="time", values="midEnd").fillna(method="ffill", axis="columns").fillna(method="bfill", axis="columns")
# C:\Users\zkr_l\AppData\Local\Temp\ipykernel_21276\3614617416.py:17: FutureWarning: DataFrame.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   px_df2 = bin_sample_df2[["stock", "date", "midEnd", "time"]].pivot(index=["stock", "date"], columns="time", values="midEnd").fillna(method="ffill", axis="columns").fillna(method="bfill", axis="columns")
#  36%|███▋      | 4/11 [01:14<02:11, 18.72s/it]C:\Users\zkr_l\AppData\Local\Temp\ipykernel_21276\3614617416.py:16: FutureWarning: DataFrame.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   px_df = bin_sample_df[["stock", "date", "midEnd", "time"]].pivot(index=["stock", "date"], columns="time", values="midEnd").fillna(method="ffill", axis="columns").fillna(method="bfill", axis="columns")
# C:\Users\zkr_l\AppData\Local\Temp\ipykernel_21276\3614617416.py:17: FutureWarning: DataFrame.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   px_df2 = bin_sample_df2[["stock", "date", "midEnd", "time"]].pivot(index=["stock", "date"], columns="time", values="midEnd").fillna(method="ffill", axis="columns").fillna(method="bfill", axis="columns")
#  45%|████▌     | 5/11 [01:32<01:52, 18.77s/it]C:\Users\zkr_l\AppData\Local\Temp\ipykernel_21276\3614617416.py:16: FutureWarning: DataFrame.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   px_df = bin_sample_df[["stock", "date", "midEnd", "time"]].pivot(index=["stock", "date"], columns="time", values="midEnd").fillna(method="ffill", axis="columns").fillna(method="bfill", axis="columns")
# C:\Users\zkr_l\AppData\Local\Temp\ipykernel_21276\3614617416.py:17: FutureWarning: DataFrame.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   px_df2 = bin_sample_df2[["stock", "date", "midEnd", "time"]].pivot(index=["stock", "date"], columns="time", values="midEnd").fillna(method="ffill", axis="columns").fillna(method="bfill", axis="columns")
#  55%|█████▍    | 6/11 [01:50<01:32, 18.53s/it]C:\Users\zkr_l\AppData\Local\Temp\ipykernel_21276\3614617416.py:16: FutureWarning: DataFrame.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   px_df = bin_sample_df[["stock", "date", "midEnd", "time"]].pivot(index=["stock", "date"], columns="time", values="midEnd").fillna(method="ffill", axis="columns").fillna(method="bfill", axis="columns")
# C:\Users\zkr_l\AppData\Local\Temp\ipykernel_21276\3614617416.py:17: FutureWarning: DataFrame.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   px_df2 = bin_sample_df2[["stock", "date", "midEnd", "time"]].pivot(index=["stock", "date"], columns="time", values="midEnd").fillna(method="ffill", axis="columns").fillna(method="bfill", axis="columns")
#  64%|██████▎   | 7/11 [02:10<01:15, 18.82s/it]C:\Users\zkr_l\AppData\Local\Temp\ipykernel_21276\3614617416.py:16: FutureWarning: DataFrame.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   px_df = bin_sample_df[["stock", "date", "midEnd", "time"]].pivot(index=["stock", "date"], columns="time", values="midEnd").fillna(method="ffill", axis="columns").fillna(method="bfill", axis="columns")
# C:\Users\zkr_l\AppData\Local\Temp\ipykernel_21276\3614617416.py:17: FutureWarning: DataFrame.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   px_df2 = bin_sample_df2[["stock", "date", "midEnd", "time"]].pivot(index=["stock", "date"], columns="time", values="midEnd").fillna(method="ffill", axis="columns").fillna(method="bfill", axis="columns")
#  73%|███████▎  | 8/11 [02:28<00:55, 18.52s/it]C:\Users\zkr_l\AppData\Local\Temp\ipykernel_21276\3614617416.py:16: FutureWarning: DataFrame.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   px_df = bin_sample_df[["stock", "date", "midEnd", "time"]].pivot(index=["stock", "date"], columns="time", values="midEnd").fillna(method="ffill", axis="columns").fillna(method="bfill", axis="columns")
# C:\Users\zkr_l\AppData\Local\Temp\ipykernel_21276\3614617416.py:17: FutureWarning: DataFrame.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   px_df2 = bin_sample_df2[["stock", "date", "midEnd", "time"]].pivot(index=["stock", "date"], columns="time", values="midEnd").fillna(method="ffill", axis="columns").fillna(method="bfill", axis="columns")
#  82%|████████▏ | 9/11 [02:46<00:36, 18.41s/it]C:\Users\zkr_l\AppData\Local\Temp\ipykernel_21276\3614617416.py:16: FutureWarning: DataFrame.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   px_df = bin_sample_df[["stock", "date", "midEnd", "time"]].pivot(index=["stock", "date"], columns="time", values="midEnd").fillna(method="ffill", axis="columns").fillna(method="bfill", axis="columns")
# C:\Users\zkr_l\AppData\Local\Temp\ipykernel_21276\3614617416.py:17: FutureWarning: DataFrame.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   px_df2 = bin_sample_df2[["stock", "date", "midEnd", "time"]].pivot(index=["stock", "date"], columns="time", values="midEnd").fillna(method="ffill", axis="columns").fillna(method="bfill", axis="columns")
#  91%|█████████ | 10/11 [03:04<00:18, 18.31s/it]C:\Users\zkr_l\AppData\Local\Temp\ipykernel_21276\3614617416.py:16: FutureWarning: DataFrame.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   px_df = bin_sample_df[["stock", "date", "midEnd", "time"]].pivot(index=["stock", "date"], columns="time", values="midEnd").fillna(method="ffill", axis="columns").fillna(method="bfill", axis="columns")
# C:\Users\zkr_l\AppData\Local\Temp\ipykernel_21276\3614617416.py:17: FutureWarning: DataFrame.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   px_df2 = bin_sample_df2[["stock", "date", "midEnd", "time"]].pivot(index=["stock", "date"], columns="time", values="midEnd").fillna(method="ffill", axis="columns").fillna(method="bfill", axis="columns")
# 100%|██████████| 11/11 [03:20<00:00, 18.22s/it]

# %%
bin_sample_df
# Out:
#                date      time stock  trade  orderFlow  hidden  auction  \
# 0        2019-11-01  09:30:00     A      0         84       0        0
# 1        2019-11-01  09:30:10     A      0         36       0        0
# 2        2019-11-01  09:30:30     A      0         34      65        0
# 3        2019-11-01  09:30:40     A      0        136       0        0
# 4        2019-11-01  09:30:50     A      0         -5       0        0
# ...             ...       ...   ...    ...        ...     ...      ...
# 1946539  2019-11-29  12:59:10   ARE      0        105      16        0
# 1946540  2019-11-29  12:59:20   ARE    -32          0       0        0
# ARE   2019-12-20     0.015     0.020     0.010     0.045     0.030     0.050
#       2019-12-23     0.015     0.010     0.005     0.025     0.015     0.020
#       2019-12-24     0.075     0.075     0.075     0.075     0.075     0.075
#       2019-12-26     0.025     0.020     0.030     0.030     0.040     0.040
#       2019-12-27     0.020     0.015     0.005     0.020     0.020     0.025
#
# time              15:59:40  15:59:50  16:00:00
# stock date
# A     2019-12-02     0.010     0.010     0.010
#       2019-12-03     0.010     0.020     0.020
#       2019-12-04     0.020     0.020     0.020
#       2019-12-05     0.010     0.010     0.010
#       2019-12-06     0.005     0.005     0.005
# ...                    ...       ...       ...
# ARE   2019-12-20     0.015     0.030     0.030
#       2019-12-23     0.020     0.030     0.030
#       2019-12-24     0.075     0.075     0.075
#       2019-12-26     0.020     0.035     0.035
#       2019-12-27     0.020     0.020     0.020
#
# [931 rows x 2341 columns]

# %%
monthly_stock_info_df
# Out:
#     stock        date    px_vol  volume
# 0       A  2019-11-01  0.000192  168255
# 1       A  2019-11-04  0.000181  101881
# 2       A  2019-11-05  0.000234  163436
# 3       A  2019-11-06  0.000224  121174
# 4       A  2019-11-07  0.000207   95653
# ..    ...         ...       ...     ...
# 975   ARE  2019-11-22  0.000223   78377
# 976   ARE  2019-11-25  0.000194   57685
# 977   ARE  2019-11-26  0.000257   92637
# 978   ARE  2019-11-27  0.000194   59014
# 979   ARE  2019-11-29  0.000214   24332
#
# [980 rows x 4 columns]

# %%
stock_info_df
# Out:
#       index stock        date    px_vol  volume
# 0         0     A  2019-11-01  0.000192  168255
# 1         1     A  2019-11-04  0.000181  101881
# 2         2     A  2019-11-05  0.000234  163436
# 3         3     A  2019-11-06  0.000224  121174
# 4         4     A  2019-11-07  0.000207   95653
# ...     ...   ...         ...       ...     ...
# 1906    926   ARE  2019-12-20  0.000225   57796
# 1907    927   ARE  2019-12-23  0.000112   45866
# 1908    928   ARE  2019-12-24  0.000135   17555
# 1909    929   ARE  2019-12-26  0.000138   24736
# 1910    930   ARE  2019-12-27  0.000141   54055
#
# [1911 rows x 5 columns]

# %%
for month_int in tqdm(range(1, 13)):
    month = '%02d' % month_int
    filename = f"inter_results_px_df_{year}{month}.csv"
    px_df = pd.read_csv(result_path+filename).set_index(["stock","date"])
    filename = f"inter_results_trade_volume_df_{year}{month}.csv"
    traded_volume_df = pd.read_csv(result_path+filename).set_index(["stock","date"])
    filename = f"inter_results_spread_df_{year}{month}.csv"
    spread_df = pd.read_csv(result_path+filename).set_index(["stock","date"])

    filename = f"adjusted_prices_{year}{month}.csv"
    px_df = px_df + np.multiply(traded_volume_df.abs(), spread_df) / 2
    px_df.to_csv(result_path+filename)
# Out:
# 100%|██████████| 12/12 [01:10<00:00,  5.89s/it]

# %%
px_df
# Out:
#                   09:30:00  09:30:10  09:30:20  09:30:30  09:30:40  09:30:50  \
# stock date
# A     2019-12-02   80.7500    80.765    80.785    81.445    80.715    80.695
